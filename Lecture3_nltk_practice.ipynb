# %% [markdown]
# ## Official document：http://www.nltk.org/book/ch01.html
# - Editor: Youngmi Huang
# - Update: 2018/04

# %%
import nltk

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader>  q
# True

# %%
# download example
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/gunpow/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader>  q
# True

# %%
# English Sentence Example
sentence = """At eight o'clock on Thursday morning
... Arthur didn't feel very good."""

# Tokenize_word
tokens_w = nltk.word_tokenize(sentence)
tokens_w
# Out:
# ['At',
#  'eight',
#  "o'clock",
#  'on',
#  'Thursday',
#  'morning',
#  '...',
#  'Arthur',
#  'did',
#  "n't",
#  'feel',
#  'very',
#  'good',
#  '.']

# %%
# Tokenize_sentence
tokens = nltk.sent_tokenize(sentence)
tokens
# Out:
# ["At eight o'clock on Thursday morning\n... Arthur didn't feel very good."]

# %% [markdown]
# ## 1.3 Searching Text

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# Search keywords
text3.concordance("lived")
# Out:
# Displaying 25 of 38 matches:
# ay when they were created . And Adam lived an hundred and thirty years , and be
# ughters : And all the days that Adam lived were nine hundred and thirty yea and
# nd thirty yea and he died . And Seth lived an hundred and five years , and bega
# ve years , and begat Enos : And Seth lived after he begat Enos eight hundred an
# welve years : and he died . And Enos lived ninety years , and begat Cainan : An
#  years , and begat Cainan : And Enos lived after he begat Cainan eight hundred
# ive years : and he died . And Cainan lived seventy years and begat Mahalaleel :
# rs and begat Mahalaleel : And Cainan lived after he begat Mahalaleel eight hund
# years : and he died . And Mahalaleel lived sixty and five years , and begat Jar
# s , and begat Jared : And Mahalaleel lived after he begat Jared eight hundred a
# and five yea and he died . And Jared lived an hundred sixty and two years , and
# o years , and he begat Eno And Jared lived after he begat Enoch eight hundred y
#  and two yea and he died . And Enoch lived sixty and five years , and begat Met
#  ; for God took him . And Methuselah lived an hundred eighty and seven years ,
#  , and begat Lamech . And Methuselah lived after he begat Lamech seven hundred
# nd nine yea and he died . And Lamech lived an hundred eighty and two years , an
# ch the LORD hath cursed . And Lamech lived after he begat Noah five hundred nin
# naan shall be his servant . And Noah lived after the flood three hundred and fi
# xad two years after the flo And Shem lived after he begat Arphaxad five hundred
# at sons and daughters . And Arphaxad lived five and thirty years , and begat Sa
# ars , and begat Salah : And Arphaxad lived after he begat Salah four hundred an
# begat sons and daughters . And Salah lived thirty years , and begat Eber : And
# y years , and begat Eber : And Salah lived after he begat Eber four hundred and
#  begat sons and daughters . And Eber lived four and thirty years , and begat Pe
# y years , and begat Peleg : And Eber lived after he begat Peleg four hundred an

# %%
# Search similar
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
# Search the common words in contexts
text1.common_contexts(["monstrous","true"])
# Out:
# the_pictures

# %%
text1.common_contexts(["monstrous","abundant"])
# Out:
# most_and

# %%
# Plot the position in the whole contexts
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America", "liberty", "constitution"])

# %% [markdown]
# ## 1.4 Counting Vocubulary

# %%
# calculate the length of total words
len(text4)
# Out:
# 149797

# %%
# calcualte the num of distinct words
len(set(text4))
# Out:
# 9913

# %%
# sorted by the distinct words
sorted(set(text4))
# Out:
# ['!',
#  '"',
#  '";',
#  '"?',
#  '$',
#  "'",
#  '(',
#  ')',
#  '),',
#  ',',
#  ',"',
#  '-',
#  '--',
#  '.',
#  '."',
#  '.)',
#  '...',
#  '....',
#  '.¡¨',
#  '000',
#  '1',
#  '100',
#  '120',
#  '125',
#  '13',
#  '14th',
#  '15th',
#  '16',
#  '1774',
#  '1776',
#  '1778',
#  '1780',
#  '1787',
#  '1789',
#  '1790',
#  '1800',
#  '1801',
#  '1812',
#  '1815',
#  '1816',
#  '1817',
#  '1818',
#  '1826',
#  '1850',
#  '1861',
#  '1868',
#  '1873',
#  '1880',
#  '1886',
#  '1890',
#  '1893',
#  '1896',
#  '1897',
#  '1898',
#  '1899',
#  '18th',
#  '1907',
#  '1917',
#  '1933',
#  '1941',
#  '1945',
#  '1963',
#  '1972',
#  '1980',
#  '1984',
#  '19th',
#  '2',
#  '20',
#  '200',
#  '200th',
#  '2017',
#  '20th',
#  '21st',
#  '225',
#  '25',
#  '3',
#  '30',
#  '30th',
#  '3d',
#  '4',
#  '40',
#  '400',
#  '41',
#  '48',
#  '4th',
#  '5',
#  '50',
#  '50th',
#  '6',
#  '60',
#  '67',
#  '6th',
#  '7',
#  '8',
#  '9',
#  ':',
#  ';',
#  '?',
#  '?"',
#  'A',
#  'AIDS',
#  'ALL',
#  'AMENDMENT',
#  'AS',
#  'Abandonment',
#  'Abhorring',
#  'About',
#  'Above',
#  'Abraham',
#  'Abroad',
#  'Accept',
#  'Across',
#  'Act',
#  'Acting',
#  'Action',
#  'Actual',
#  'Adams',
#  'Additional',
#  'Address',
#  'Administered',
#  'Administration',
#  'Administrations',
#  'Advance',
#  'Advancing',
#  'Afghanistan',
#  'Africa',
#  'African',
#  'After',
#  'Again',
#  'Age',
#  'Agriculture',
#  'Alamo',
#  'All',
#  'Alleghanies',
#  'Almighty',
#  'Almost',
#  'Along',
#  'Already',
#  'Although',
#  'Always',
#  'Amelia',
#  'Amen',
#  'America',
#  'American',
#  'Americanism',
#  'Americans',
#  'Americanâ',
#  'Americas',
#  'Amid',
#  'Amidst',
#  'Among',
#  'Amongst',
#  'An',
#  'And',
#  'Andes',
#  'Annihilate',
#  'Another',
#  'Anthony',
#  'Anxiety',
#  'Anxious',
#  'Any',
#  'Anyone',
#  'Apollo',
#  'Appalachia',
#  'Appreciating',
#  'Apprehension',
#  'April',
#  'Arbitration',
#  'Archibald',
#  'Are',
#  'Argonne',
#  'Arlington',
#  'Armies',
#  'Army',
#  'Articles',
#  'As',
#  'Asia',
#  'Asiatic',
#  'Assessing',
#  'Assistance',
#  'Association',
#  'Assuring',
#  'At',
#  'Athens',
#  'Atlantic',
#  'Attention',
#  'Author',
#  'BUSINESS',
#  'BY',
#  'Bad',
#  'Baker',
#  'Baltimore',
#  'Barbary',
#  'Batavian',
#  'Beach',
#  'Because',
#  'Before',
#  'Being',
#  'Belief',
#  'Believing',
#  'Bell',
#  'Belleau',
#  'Beneath',
#  'Beneficent',
#  'Bernardin',
#  'Besides',
#  'Between',
#  'Beyond',
#  'Bible',
#  'Bicentennial',
#  'Biden',
#  'Bill',
#  'Black',
#  'Blessed',
#  'Board',
#  'Bolivar',
#  'Boston',
#  'Both',
#  'Britain',
#  'Britannic',
#  'British',
#  'Brown',
#  'Brutus',
#  'Budapest',
#  'Bureau',
#  'Burger',
#  'Burma',
#  'Bush',
#  'Business',
#  'But',
#  'Buy',
#  'By',
#  'CONCLUSION',
#  'CONGRESS',
#  'COOPERATION',
#  'CRIMINAL',
#  'Cabinet',
#  'Caesar',
#  'California',
#  'Called',
#  'Calmness',
#  'Calvin',
#  'Camillus',
#  'Can',
#  'Canal',
#  'Cantons',
#  'Cape',
#  'Capital',
#  'Capitol',
#  'Cardinal',
#  'Care',
#  'Carolina',
#  'Carter',
#  'Cemetery',
#  'Central',
#  'Century',
#  'Certain',
#  'Chairman',
#  'Chamber',
#  'Change',
#  'Charta',
#  'Charter',
#  'Cheney',
#  'Chief',
#  'China',
#  'Chop',
#  'Chosen',
#  'Chosin',
#  'Christian',
#  'Christianity',
#  'Christians',
#  'Christmas',
#  'Christs',
#  'Church',
#  'Churchill',
#  'Cincinnati',
#  'Citizens',
#  'Civil',
#  'Civility',
#  'Claiming',
#  'Clay',
#  'Clearly',
#  'Clergy',
#  'Clinton',
#  'Closely',
#  'Coast',
#  'Code',
#  'Cold',
#  'Coleman',
#  'Colonel',
#  'Columbia',
#  'Comfort',
#  'Commander',
#  'Commendable',
#  'Commerce',
#  'Commission',
#  'Commissioners',
#  'Common',
#  'Commons',
#  'Commonwealth',
#  'Communications',
#  'Communism',
#  'Communist',
#  'Communists',
#  'Compact',
#  'Compared',
#  'Conceived',
#  'Conceiving',
#  'Concord',
#  'Conditions',
#  'Confederacy',
#  'Confederation',
#  'Confidence',
#  'Confident',
#  'Confidently',
#  'Confusion',
#  'Congress',
#  'Congressional',
#  'Congressman',
#  'Connected',
#  'Conscious',
#  'Considering',
#  'Constantly',
#  'Constitution',
#  'Constitutional',
#  'Contemplating',
#  'Content',
#  'Continue',
#  'Convention',
#  'Convinced',
#  'Cook',
#  'Coolidge',
#  'Corporations',
#  'Cortes',
#  'Country',
#  'Countrymen',
#  'Courage',
#  'Court',
#  'Covenant',
#  'Creator',
#  'Crime',
#  'Croix',
#  'Cromwell',
#  'Cuba',
#  'Cuban',
#  'Cubans',
#  'Cures',
#  'Curtii',
#  'DC',
#  'Dakota',
#  'Dakotas',
#  'Dangers',
#  'Dark',
#  'David',
#  'Day',
#  'December',
#  'Decii',
#  'Declaration',
#  'Deeply',
#  'Delano',
#  'Democracy',
#  'Democratic',
#  'Democrats',
#  'Department',
#  'Departments',
#  'Depression',
#  'Descending',
#  'Destructive',
#  'Detroit',
#  'Did',
#  'Difficult',
#  'Dingley',
#  'Directly',
#  'Dirksen',
#  'Discord',
#  'Discouraging',
#  'Disease',
#  'Distinct',
#  'District',
#  'Distrust',
#  'Divided',
#  'Divine',
#  'Division',
#  'Do',
#  'Does',
#  'Doing',
#  'Dole',
#  'Domestic',
#  'Domingo',
#  'Dr',
#  'Dream',
#  'Due',
#  'Dulled',
#  'During',
#  'EDUCATION',
#  'EIGHTEENTH',
#  'ELECTION',
#  'ENFORCEMENT',
#  'Each',
#  'Earth',
#  'East',
#  'Economic',
#  'Economy',
#  'Egypt',
#  'Eight',
#  'Eisenhower',
#  'Elected',
#  'Emerson',
#  'Emperor',
#  'Employed',
#  'Encountering',
#  'Encouraging',
#  'Ending',
#  'Endowed',
#  'Engineers',
#  'England',
#  'English',
#  'Enough',
#  'Entering',
#  'Enterprises',
#  'Envy',
#  'Equal',
#  'Equality',
#  'Equally',
#  'Especially',
#  'Establishment',
#  'Europe',
#  'European',
#  'Eve',
#  'Even',
#  'Events',
#  'Eventually',
#  'Ever',
#  'Every',
#  'Everyone',
#  'Everywhere',
#  'Executive',
#  'Existing',
#  'Expenditure',
#  'Experience',
#  'Experiencing',
#  'FAILURE',
#  'FROM',
#  'Faced',
#  'Falls',
#  'Far',
#  'Farewell',
#  'Father',
#  'Fathers',
#  'February',
#  'Federal',
#  'Federalists',
#  'Fellow',
#  'Fifty',
#  'Finally',
#  'First',
#  'Florida',
#  'Floridas',
#  'Following',
#  'Fondly',
#  'For',
#  'Force',
#  'Forces',
#  'Foreign',
#  'Forge',
#  'Fort',
#  'Fortunate',
#  'Fortunately',
#  'Forty',
#  'Founders',
#  'Founding',
#  'Fountain',
#  'Four',
#  'Fourth',
#  'France',
#  'Franklin',
#  'Freed',
#  'Freedom',
#  'French',
#  'Friends',
#  'From',
#  'Front',
#  'Fruitful',
#  'Fully',
#  'G',
#  'GOVERNMENT',
#  'Gatun',
#  'Gaul',
#  'General',
#  'Genius',
#  'George',
#  'Germany',
#  'Gettysburg',
#  'Ghent',
#  'Gillis',
#  'Give',
#  'Giver',
#  'God',
#  'Godsend',
#  'Goethals',
#  'Golden',
#  'Good',
#  'Gore',
#  'Government',
#  'Governments',
#  'Grant',
#  'Grave',
#  'Great',
#  'Greater',
#  'Greatness',
#  'Greece',
#  'Gross',
#  'Growing',
#  'Guadalcanal',
#  'Guarantees',
#  'Guided',
#  'Gulf',
#  'HEALTH',
#  'Had',
#  'Hague',
#  'Half',
#  'Hall',
#  'Hand',
#  'Happily',
#  'Happiness',
#  'Happy',
#  'Hard',
#  'Has',
#  'Hatfield',
#  'Have',
#  'Having',
#  'He',
#  'Heads',
#  'Heaven',
#  'Heavenly',
#  'Help',
#  'Helvetic',
#  'Hemisphere',
#  'Hence',
#  'Here',
#  'Herein',
#  'High',
#  'Higher',
#  'Hill',
#  'Him',
#  'Hindus',
#  'His',
#  'History',
#  'Hitherto',
#  'Holy',
#  'Homes',
#  'Homestead',
#  'Honesty',
#  'Honorable',
#  'Honored',
#  'Honoring',
#  'Hope',
#  'Horn',
#  'House',
#  'Houses',
#  'How',
#  'However',
#  'Human',
#  'Humanity',
#  'Humphrey',
#  'Hundreds',
#  'I',
#  'II',
#  'INVESTIGATION',
#  'Idle',
#  'If',
#  'Ill',
#  'Illiteracy',
#  'Immunity',
#  'In',
#  'Inauguration',
#  'Inconsiderable',
#  'Indeed',
#  'Independence',
#  'Independently',
#  'Indian',
#  'Indians',
#  'Indies',
#  'Indo',
#  'Indulging',
#  'Industrial',
#  'Industry',
#  'Infinite',
#  'Information',
#  'Instead',
#  'Instinctively',
#  'Intelligence',
#  'Intentions',
#  'Internal',
#  'International',
#  'Internet',
#  'Interstate',
#  'Intrusted',
#  'Invasions',
#  'Investment',
#  'Invisible',
#  'Iowa',
#  'Iraq',
#  'Irritated',
#  'Is',
#  'Isaiah',
#  'Islamic',
#  'Island',
#  'Islands',
#  'Isles',
#  'Israel',
#  'Isthmus',
#  'It',
#  'Italy',
#  'Its',
#  'Iwo',
#  'JUSTICE',
#  'Janeiro',
#  'January',
#  'Jealous',
#  'Jefferson',
#  'Jericho',
#  'Jews',
#  'Jima',
#  'John',
#  'Johnson',
#  'Joseph',
#  'Julia',
#  'July',
#  'Just',
#  'Justice',
#  'K',
#  'Kansas',
#  'Khe',
#  'Kindly',
#  'King',
#  'Knowing',
#  'Koran',
#  'Korea',
#  'Labor',
#  'Laboring',
#  'Lady',
#  'Lakes',
#  'Latent',
#  'Laws',
#  'Leader',
#  'League',
#  'Legislation',
#  'Legislature',
#  'Legitimate',
#  'Less',
#  'Let',
#  'Liberty',
#  'Like',
#  'Likewise',
#  'Limited',
#  'Lincoln',
#  'Lives',
#  'Loans',
#  'Local',
#  'Long',
#  'Look',
#  'Looking',
#  'Lord',
#  'Louisiana',
#  'Love',
#  'Loyalty',
#  'Luther',
#  'Lynchings',
#  'MANDATES',
#  'MY',
#  'MacLeish',
#  'Madison',
#  'Magistrate',
#  'Magna',
#  'Magnifying',
#  'Majesty',
#  'Majority',
#  'Make',
#  'Maker',
#  'Malaya',
#  'Mall',
#  'Manifestly',
#  'Mankind',
#  'Many',
#  'March',
#  'Mars',
#  'Martin',
#  'Massachusetts',
#  'Masses',
#  'Mathias',
#  'May',
#  'Mayflower',
#  'Meantime',
#  'Measures',
#  'Medicaid',
#  'Medicare',
#  'Mediterranean',
#  'Melancholy',
#  'Members',
#  'Memorial',
#  'Men',
#  'Mental',
#  'Mexico',
#  'Micah',
#  'Michael',
#  'Michelle',
#  'Middle',
#  'Mill',
#  'Mind',
#  'Mindful',
#  'Minorities',
#  'Mischievous',
#  'Misled',
#  'Miss',
#  'Mississippi',
#  'Missouri',
#  'Mitchell',
#  'Modern',
#  'Moment',
#  'Mondale',
#  'Monday',
#  'Monroe',
#  'Montana',
#  'Monticello',
#  'Moomaw',
#  'Moon',
#  'Moral',
#  'More',
#  'Moreover',
#  'Mormon',
#  'Moscow',
#  'Most',
#  'Mothers',
#  'Mount',
#  'Mountains',
#  'Mr',
#  'Mrs',
#  'Much',
#  'Muslim',
#  'Muslims',
#  'Must',
#  'My',
#  'NATIONAL',
#  'Nation',
#  'National',
#  'Nations',
#  'Nature',
#  'Naval',
#  'Navy',
#  'Nearly',
#  'Nebraska',
#  'Negligence',
#  'Negro',
#  'Negroes',
#  'Neill',
#  'Neither',
#  'Never',
#  'New',
#  'Newtown',
#  'Next',
#  'Nixon',
#  'No',
#  'None',
#  'Nor',
#  'Normandy',
#  'North',
#  'Northerners',
#  'Not',
#  'Nothing',
#  'Notwithstanding',
#  'November',
#  'Now',
#  'Nowhere',
#  'O',
#  'OF',
#  'OTHER',
#  'OUR',
#  'Obama',
#  'Occasionally',
#  'Ocean',
#  'Oceans',
#  'Octavius',
#  'October',
#  'Of',
#  'Off',
#  'Offices',
#  'Ohio',
#  'Old',
#  'Omaha',
#  'Omnipotence',
#  'On',
#  'Once',
#  'One',
#  'Only',
#  'Opportunism',
#  'Opportunity',
#  'Or',
#  'Order',
#  'Oregon',
#  'Orient',
#  'Orleans',
#  'Other',
#  'Others',
#  'Our',
#  'Ours',
#  'Out',
#  'Over',
#  'Overlooking',
#  'Overwhelmingly',
#  'PARTY',
#  'PEACE',
#  'PROGRESS',
#  'PUBLIC',
#  'Pacific',
#  'Page',
#  'Panama',
#  'Parchment',
#  'Parent',
#  'Parents',
#  'Paris',
#  'Parliament',
#  'Partial',
#  'Party',
#  'Passing',
#  'Passion',
#  'Patriotism',
#  'Patron',
#  'Peabody',
#  'Peace',
#  'Peking',
#  'Penetrating',
#  'Pennsylvania',
#  'People',
#  'Peoples',
#  'Perceiving',
#  'Perfection',
#  'Perhaps',
#  'Permanent',
#  'Perpetual',
#  'Perpetuity',
#  'Persian',
#  'Persistent',
#  'Personally',
#  'Petitions',
#  'Philadelphia',
#  'Philippine',
#  'Philippines',
#  'Physically',
#  'Plainly',
#  'Pledge',
#  'Plenty',
#  'Political',
#  'Politicians',
#  'Pool',
#  'Pork',
#  'Porto',
#  'Ports',
#  'Position',
#  'Possessing',
#  'Posterity',
#  'Potomac',
#  'Power',
#  'Powerful',
#  'Powers',
#  'Practices',
#  'Preeminently',
#  'Prejudice',
#  'Present',
#  'Presidency',
#  'President',
#  'Presidential',
#  'Presidents',
#  'Previous',
#  'Price',
#  'Prices',
#  'Primarily',
#  'Problems',
#  'Proceeding',
#  'Product',
#  'Profound',
#  'Progress',
#  'Proofs',
#  'Prophets',
#  'Prosperity',
#  'Protection',
#  'Protector',
#  'Providence',
#  'Province',
#  'Public',
#  'Purposes',
#  'Putting',
#  'Quayle',
#  'RELATION',
#  'RESPONSIBILITIES',
#  'Race',
#  'Rainbow',
#  'Raised',
#  'Rather',
#  'Reagan',
#  'Realizing',
#  'Reasoned',
#  'Recall',
#  'Recent',
#  'Recognition',
#  'Recognizing',
#  'Reconstruction',
#  'Red',
#  'Reflecting',
#  'Reform',
#  'Reforms',
#  'Relief',
#  'Relying',
#  'Removing',
#  'Renewed',
#  'Repeated',
#  'Representative',
#  'Representatives',
#  'Republic',
#  'Republican',
#  'Republicans',
#  'Republics',
#  'Reservoir',
#  'Resolved',
#  'Respecting',
#  'Resting',
#  'Restoration',
#  'Retrospect',
#  'Returning',
#  'Reverend',
#  'Revolution',
#  'Revolutionary',
#  'Rico',
#  'Rights',
#  'Rigid',
#  'Rio',
#  'River',
#  'Roberts',
#  'Rocky',
#  'Roman',
#  'Rome',
#  'Roosevelt',
#  'Root',
#  'Rule',
#  'Ruler',
#  'Russia',
#  'SESSION',
#  'SPECIAL',
#  'SYSTEM',
#  'Sabine',
#  'Sacredly',
#  'Sahn',
#  'Salerno',
#  'Sanitary',
#  'Santo',
#  'Savior',
#  'Scandinavia',
#  'Science',
#  'Scientists',
#  'Scipios',
#  'Scripture',
#  'Scythia',
#  'Second',
#  'Secretary',
#  'Sectionalism',
#  'Security',
#  'Seeking',
#  'Self',
#  'Selma',
#  'Senate',
#  'Senator',
#  'Senators',
#  'Seneca',
#  'September',
#  'Sermon',
#  'Service',
#  'Shall',
#  'She',
#  'Shortly',
#  'Should',
#  'Sinai',
#  'Since',
#  'Situated',
#  'Slowly',
#  'Small',
#  'So',
#  'Social',
#  'Societies',
#  'Society',
#  'Solemnly',
#  'Somalia',
#  'Some',
#  'Something',
#  'Sometimes',
#  'South',
#  'Southern',
#  'Sovereignty',
#  'Soviet',
#  'Soviets',
#  'Spain',
#  ...]

# %%
# lexical diversity
def lexical_diversity(text):
    return len(set(text)) / len(text)

lexical_diversity(text3)
# Out:
# 0.06230453042623537

# %%
# view sent1
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
# view sent2
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
# merge sent1 and sent2
sent1 + sent2
# Out:
# ['Call',
#  'me',
#  'Ishmael',
#  '.',
#  'The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
# Stopwords of English (default)
from nltk.corpus import stopwords
stopwords.words("english")
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Stopwords of italian (default)
from nltk.corpus import stopwords
stopwords.words("italian")
# Out:
# ['ad',
#  'al',
#  'allo',
#  'ai',
#  'agli',
#  'all',
#  'agl',
#  'alla',
#  'alle',
#  'con',
#  'col',
#  'coi',
#  'da',
#  'dal',
#  'dallo',
#  'dai',
#  'dagli',
#  'dall',
#  'dagl',
#  'dalla',
#  'dalle',
#  'di',
#  'del',
#  'dello',
#  'dei',
#  'degli',
#  'dell',
#  'degl',
#  'della',
#  'delle',
#  'in',
#  'nel',
#  'nello',
#  'nei',
#  'negli',
#  'nell',
#  'negl',
#  'nella',
#  'nelle',
#  'su',
#  'sul',
#  'sullo',
#  'sui',
#  'sugli',
#  'sull',
#  'sugl',
#  'sulla',
#  'sulle',
#  'per',
#  'tra',
#  'contro',
#  'io',
#  'tu',
#  'lui',
#  'lei',
#  'noi',
#  'voi',
#  'loro',
#  'mio',
#  'mia',
#  'miei',
#  'mie',
#  'tuo',
#  'tua',
#  'tuoi',
#  'tue',
#  'suo',
#  'sua',
#  'suoi',
#  'sue',
#  'nostro',
#  'nostra',
#  'nostri',
#  'nostre',
#  'vostro',
#  'vostra',
#  'vostri',
#  'vostre',
#  'mi',
#  'ti',
#  'ci',
#  'vi',
#  'lo',
#  'la',
#  'li',
#  'le',
#  'gli',
#  'ne',
#  'il',
#  'un',
#  'uno',
#  'una',
#  'ma',
#  'ed',
#  'se',
#  'perché',
#  'anche',
#  'come',
#  'dov',
#  'dove',
#  'che',
#  'chi',
#  'cui',
#  'non',
#  'più',
#  'quale',
#  'quanto',
#  'quanti',
#  'quanta',
#  'quante',
#  'quello',
#  'quelli',
#  'quella',
#  'quelle',
#  'questo',
#  'questi',
#  'questa',
#  'queste',
#  'si',
#  'tutto',
#  'tutti',
#  'a',
#  'c',
#  'e',
#  'i',
#  'l',
#  'o',
#  'ho',
#  'hai',
#  'ha',
#  'abbiamo',
#  'avete',
#  'hanno',
#  'abbia',
#  'abbiate',
#  'abbiano',
#  'avrò',
#  'avrai',
#  'avrà',
#  'avremo',
#  'avrete',
#  'avranno',
#  'avrei',
#  'avresti',
#  'avrebbe',
#  'avremmo',
#  'avreste',
#  'avrebbero',
#  'avevo',
#  'avevi',
#  'aveva',
#  'avevamo',
#  'avevate',
#  'avevano',
#  'ebbi',
#  'avesti',
#  'ebbe',
#  'avemmo',
#  'aveste',
#  'ebbero',
#  'avessi',
#  'avesse',
#  'avessimo',
#  'avessero',
#  'avendo',
#  'avuto',
#  'avuta',
#  'avuti',
#  'avute',
#  'sono',
#  'sei',
#  'è',
#  'siamo',
#  'siete',
#  'sia',
#  'siate',
#  'siano',
#  'sarò',
#  'sarai',
#  'sarà',
#  'saremo',
#  'sarete',
#  'saranno',
#  'sarei',
#  'saresti',
#  'sarebbe',
#  'saremmo',
#  'sareste',
#  'sarebbero',
#  'ero',
#  'eri',
#  'era',
#  'eravamo',
#  'eravate',
#  'erano',
#  'fui',
#  'fosti',
#  'fu',
#  'fummo',
#  'foste',
#  'furono',
#  'fossi',
#  'fosse',
#  'fossimo',
#  'fossero',
#  'essendo',
#  'faccio',
#  'fai',
#  'facciamo',
#  'fanno',
#  'faccia',
#  'facciate',
#  'facciano',
#  'farò',
#  'farai',
#  'farà',
#  'faremo',
#  'farete',
#  'faranno',
#  'farei',
#  'faresti',
#  'farebbe',
#  'faremmo',
#  'fareste',
#  'farebbero',
#  'facevo',
#  'facevi',
#  'faceva',
#  'facevamo',
#  'facevate',
#  'facevano',
#  'feci',
#  'facesti',
#  'fece',
#  'facemmo',
#  'faceste',
#  'fecero',
#  'facessi',
#  'facesse',
#  'facessimo',
#  'facessero',
#  'facendo',
#  'sto',
#  'stai',
#  'sta',
#  'stiamo',
#  'stanno',
#  'stia',
#  'stiate',
#  'stiano',
#  'starò',
#  'starai',
#  'starà',
#  'staremo',
#  'starete',
#  'staranno',
#  'starei',
#  'staresti',
#  'starebbe',
#  'staremmo',
#  'stareste',
#  'starebbero',
#  'stavo',
#  'stavi',
#  'stava',
#  'stavamo',
#  'stavate',
#  'stavano',
#  'stetti',
#  'stesti',
#  'stette',
#  'stemmo',
#  'steste',
#  'stettero',
#  'stessi',
#  'stesse',
#  'stessimo',
#  'stessero',
#  'stando']

# %% [markdown]
# ## Using NLTK to do Chinese NLP processing (also colaborating with jieba)
# ## 中文文本也可以用nltk =>和jieba搭配使用

# %%
# import data
import jieba
import jieba.analyse
import matplotlib.pyplot as plt

# %%
with open("data/mayday.txt") as f1:
    for line in f1:
        corpus = nltk.text.Text(jieba.analyse.extract_tags(line))
        corpus.concordance("我們")
f1.close()
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.730 seconds.
# Prefix dict has been built successfully.
# no matches
# Displaying 1 of 1 matches:
#  我們 不曾 哪裡 相識 那個 場景 出現 相遇 每秒 那一刻 我會 充滿 如果
# Displaying 1 of 1 matches:
#  我們 好好 變老 時間 喧囂 最後的 知道 大人 失散多年 寫成 想養 每個 場
# Displaying 1 of 1 matches:
#  我們 人生 快樂 無論 一個 期待 然後呢 回憶 也許 走著 並肩 追尋了 親愛
# Displaying 1 of 1 matches:
# 未央 天未亮 倖存 沙場 淚未 心未涼 什麼 此生 狂妄 盼望 思念 遺忘 我們 依然 魑魅 一份 解愁 城牆
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# oh party hey let go night lonely 我們 對動物 many 瘋狂 goodbye 覺悟 good times 日出
# no matches
# no matches
# Displaying 1 of 1 matches:
# 一個 兄弟 我們 這樣 怎樣 一點 一次 身旁 人生 一場 變成 別來 無恙 抬頭 永遠 時
# no matches
# Displaying 1 of 1 matches:
# 盡頭 怎麼樣 終點 有光 我們 成名 那夜 起點 可會亮 綻放 回頭望 一雙 風光 那路 怎樣 少年 一站
# Displaying 1 of 1 matches:
# 變成 交響 我心 每個 孤單 一個 沒人 還有 崩壞 旋律 默默 合唱 我們 戰場 一線 無論 一樣 至少 天亮 心中
# no matches
# no matches
# Displaying 1 of 1 matches:
#  我們 人們 未來 無數 如海 怎樣 無數命 運流轉 相異 航向 汪洋 小孩 打造
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
#  我們 任意 那個 走過 唱片 無數 盡歲 搭著 肩環遊 無法 遺忘 光輝 門外
# no matches
# no matches
# no matches
# no matches
# no matches
# Displaying 1 of 1 matches:
# 突然 那麼 回憶 好想你 聽到 我們 最怕 空氣 安靜 關心 翻滾 絞痛 悲傷 哪裡 過得 快樂 鋒利 平息 委
# no matches
# no matches
# no matches
# no matches
# no matches

# %%
import jieba.analyse
raw=open("data/mayday.txt").read() 
print("similar: ")
lyrics=nltk.text.Text(jieba.cut(raw))
lyrics.similar("我們")

print("common_contexts: ")
lyrics.common_contexts(["我們","我"])
# Out:
# similar:
# 我 青春 身邊 完美 難題 倔強 地方 街 路 陷阱 空氣 眼中 憤青 剝開 破壞
# common_contexts:
# 讓_不

# %%
# open single.txt data
raw=open("data/single.txt").read() 
single=nltk.text.Text(jieba.cut(raw))

# %%
sorted(set(single))
# Out:
# [' ',
#  'ORZ',
#  'happy',
#  'ing',
#  'love',
#  '\u3000',
#  '一台',
#  '上',
#  '不會',
#  '不行',
#  '也',
#  '了',
#  '但是',
#  '你',
#  '係',
#  '像是',
#  '到',
#  '半夜',
#  '卻',
#  '命',
#  '噴射機',
#  '坐',
#  '好聞勝過',
#  '就',
#  '就是',
#  '心情',
#  '心跳',
#  '忘記',
#  '戀愛',
#  '我',
#  '扁平足',
#  '改變',
#  '整個',
#  '昏',
#  '是',
#  '有',
#  '未來',
#  '某',
#  '某人',
#  '某分',
#  '某地',
#  '某年某月',
#  '某日',
#  '某時',
#  '某種',
#  '此刻',
#  '水能',
#  '永遠',
#  '沒關',
#  '照進',
#  '煮粥',
#  '熬夜',
#  '爆肝',
#  '生命',
#  '的',
#  '秒',
#  '空氣',
#  '維他',
#  '聊天',
#  '能',
#  '裡',
#  '認識',
#  '讓',
#  '超感謝',
#  '載舟',
#  '逛成',
#  '逛街',
#  '都',
#  '重新',
#  '重生',
#  '陪',
#  '陽光',
#  '飽',
#  '餵',
#  '黃',
#  '黎明']

# %%
len(set(single))
# Out:
# 76

# %%
len(single)
# Out:
# 244

# %%
# lexical_diversity
lexical_diversity(single)
# Out:
# 0.3114754098360656

# %%
# matplotlib set up to demonstrate Chinese words 
from matplotlib.font_manager import _rebuild
_rebuild()

# %%
# Plot the position in the whole contexts
plt.figure(figsize=(10, 5)) 
plt.rcParams['font.sans-serif'] = 'SimHei'
single.dispersion_plot(["love","戀愛","ing","happy"])
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# /home/gunpow/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 25088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/gunpow/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 24859 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/gunpow/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 25088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/gunpow/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 24859 missing from current font.
#   font.set_text(s, 0, flags=flags)
